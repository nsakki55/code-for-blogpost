# %%
import pandas as pd

# %%
df = pd.read_csv("memray-csv-train.py.99131.csv")

# %%
df
# Out:
#      allocator  num_allocations    size  tid thread_name  \
# 0         MMAP                1  262144    1         0x1
# 1         MMAP                1    4080    1         0x1
# 2         MMAP                1  262144    1         0x1
# 3         MMAP                1  262144    1         0x1
# 4         MMAP                1  262144    1         0x1
# ...        ...              ...     ...  ...         ...
# 8325    MALLOC                1    2208    1         0x1
# 8326    MALLOC               12    3761    1         0x1
# 8327    MALLOC                2    1672    1         0x1
# 8328    MALLOC                1     576    1         0x1
# 8329    MALLOC                1    1722    1         0x1
#
#                                             stack_trace
# 0     load_csv_data;/Users/satsuki/.pyenv/versions/3...
# 1     _load_lib;/Users/satsuki/.pyenv/versions/3.8.7...
# 2     Cluster;/Users/satsuki/.pyenv/versions/3.8.7/e...
# ...
